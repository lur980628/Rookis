# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
#고양이  
import json
from pprint import pprint

base_url= 'https://www.pimfyvirus.com/dataurl_action/homeprotectionlist02/p=/search/02/p={}//'
# print(type(base_url))


req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest" #파일구조가 Json이라 필요 
}

cat_data_list = list()

for  i in range(1,20): #페이지 범위 
    url=base_url.format(i)
    #network에서 응답이 post로 처리하게 되어있음 
    res=requests.post(url,headers=req_header)

    

    if(res.ok):
        # print(res.url)
        data = res.json()
        
        for item in data.get('lst',[]):
            cat_data_dict = dict()
            
            link = item['wish']
            cat_id = link.strip('/').split('/')[-1]     
            tags=item['tag']  
            breed = item['info23']
            date = item['info2']
            t2 = item['t2']

            parts = t2.split("/")
            name = parts[0] 
            gender = parts[1] 
            weight = parts[2] 

            #dict 저장 
            cat_data_dict['ID']= cat_id
            cat_data_dict['tags']= tags
            cat_data_dict['이름']= name
            cat_data_dict['성별']= gender
            cat_data_dict['몸무게']= weight
            cat_data_dict['종']= breed
            cat_data_dict['공고날짜 ']= date
            
            cat_data_list.append(cat_data_dict)                 
    else:
        print(f'Error Code = {res.status_code}') 


print(len(cat_data_list))
pprint(cat_data_list)
# Out:
# 205
# [{'ID': '2950',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-07-26',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '나기 외 새끼고양이',
#   '종': '믹스'},
#  {'ID': '2927',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-07-21',
#   '몸무게': '08kg',
#   '성별': '여',
#   '이름': '달봉이',
#   '종': '믹스'},
#  {'ID': '2897',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-16',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '콩이',
#   '종': '믹스'},
#  {'ID': '2893',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-15',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '로담',
#   '종': '품종'},
#  {'ID': '2860',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-10',
#   '몸무게': '06kg',
#   '성별': '여',
#   '이름': '로아',
#   '종': '믹스'},
#  {'ID': '2851',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-07-09',
#   '몸무게': '08kg',
#   '성별': '남',
#   '이름': '흑미',
#   '종': '믹스'},
#  {'ID': '2840',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '방울이',
#   '종': '믹스'},
#  {'ID': '2839',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '초롱이',
#   '종': '믹스'},
#  {'ID': '2832',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '초롱이',
#   '종': '믹스'},
#  {'ID': '2831',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '강이',
#   '종': '믹스'},
#  {'ID': '2830',
#   'tags': ['임보가능', '단기임보'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '동물구조119_누룽지',
#   '종': '믹스'},
#  {'ID': '2813',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-07-06',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '모카',
#   '종': '믹스'},
#  {'ID': '2802',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-07-02',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '단비',
#   '종': '믹스'},
#  {'ID': '2801',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-07-02',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '나나',
#   '종': '믹스'},
#  {'ID': '2795',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-07-02',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '코모',
#   '종': '믹스'},
#  {'ID': '2756',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-06-25',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '루루',
#   '종': '믹스'},
#  {'ID': '2747',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-06-24',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '땅콩이',
#   '종': '믹스'},
#  {'ID': '2712',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-06-19',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '네발친_오이',
#   '종': '믹스'},
#  {'ID': '2711',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-06-19',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '네발친_양파',
#   '종': '믹스'},
#  {'ID': '2708',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-06-19',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '네발친_(옥)수수',
#   '종': '믹스'},
#  {'ID': '2707',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-06-19',
#   '몸무게': '6kg',
#   '성별': '남',
#   '이름': '동물구조119_아',
#   '종': '믹스'},
#  {'ID': '2694',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-06-17',
#   '몸무게': '1kg (입양시 중성화 지원)',
#   '성별': '여',
#   '이름': '깨발랄 &apos;딩딩이&apos;',
#   '종': '믹스'},
#  {'ID': '2693',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-06-17',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '엄마터앙',
#   '종': '품종'},
#  {'ID': '2665',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-06-12',
#   '몸무게': '6kg',
#   '성별': '남',
#   '이름': '동물구조119_부엉이',
#   '종': '믹스'},
#  {'ID': '2662',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-06-12',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '아들터앙',
#   '종': '품종'},
#  {'ID': '2660',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-06-11',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '유월',
#   '종': '믹스'},
#  {'ID': '2633',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-06-07',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '모찌',
#   '종': '품종'},
#  {'ID': '2611',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-06-05',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '타코',
#   '종': '믹스'},
#  {'ID': '2587',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-06-03',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '네발친_순돌이',
#   '종': '믹스'},
#  {'ID': '2585',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-06-03',
#   '몸무게': '03kg',
#   '성별': '남',
#   '이름': '울이',
#   '종': '믹스'},
#  {'ID': '2575',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-06-02',
#   '몸무게': '6kg',
#   '성별': '여',
#   '이름': '지원이',
#   '종': '믹스'},
#  {'ID': '2558',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-06-01',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '다찌',
#   '종': '믹스'},
#  {'ID': '2550',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-05-30',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '꽃돌이',
#   '종': '믹스'},
#  {'ID': '2537',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-05-29',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '시루',
#   '종': '믹스'},
#  {'ID': '2533',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-05-28',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '나기',
#   '종': '믹스'},
#  {'ID': '2501',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-05-26',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '이트',
#   '종': '품종'},
#  {'ID': '2500',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-05-26',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '박새로이 ',
#   '종': '품종'},
#  {'ID': '2477',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-05-24',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '앙금이',
#   '종': '믹스'},
#  {'ID': '2476',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-05-24',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '호동이',
#   '종': '믹스'},
#  {'ID': '2475',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-05-24',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '소망이',
#   '종': '믹스'},
#  {'ID': '2396',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-05-16',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '제리',
#   '종': '믹스'},
#  {'ID': '2318',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-04-30',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '삼식',
#   '종': '믹스'},
#  {'ID': '2198',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-04-13',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '뚱이',
#   '종': '믹스'},
#  {'ID': '2191',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-04-12',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '아치',
#   '종': '품종'},
#  {'ID': '2190',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-04-12',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '이쁜이',
#   '종': '품종'},
#  {'ID': '2189',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-04-12',
#   '몸무게': '6kg',
#   '성별': '여',
#   '이름': '꽃님',
#   '종': '품종'},
#  {'ID': '2168',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-04-09',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '삼동&amp;삼월 (방사위기)',
#   '종': '믹스'},
#  {'ID': '2135',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-04-04',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '미아',
#   '종': '믹스'},
#  {'ID': '2093',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-03-28',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '로웰이',
#   '종': '믹스'},
#  {'ID': '2080',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-27',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '동물구조119_동백',
#   '종': None},
#  {'ID': '2059',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-24',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '럭키',
#   '종': None},
#  {'ID': '1943',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-06',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '예삐',
#   '종': None},
#  {'ID': '1941',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-03-06',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '콩돌이',
#   '종': '믹스'},
#  {'ID': '1931',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '삼동이',
#   '종': '믹스'},
#  {'ID': '1930',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '공원 삼색이',
#   '종': '믹스'},
#  {'ID': '1929',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '공원 코점이',
#   '종': None},
#  {'ID': '1928',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '강동냥이_치즈',
#   '종': None},
#  {'ID': '1927',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '강동냥이_크림',
#   '종': None},
#  {'ID': '1926',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '7kg',
#   '성별': '남',
#   '이름': '강동냥이_라떼',
#   '종': None},
#  {'ID': '1925',
#   'tags': ['임보가능', '일반임보'],
#   '공고날짜 ': '2025-03-03',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '강동냥이_쫄랑',
#   '종': None},
#  {'ID': '1917',
#   'tags': ['임보가능', '릴레이임보'],
#   '공고날짜 ': '2025-03-01',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '네발친_하니',
#   '종': '품종'},
#  {'ID': '1735',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-02-04',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '깅코',
#   '종': '믹스'},
#  {'ID': '1716',
#   'tags': ['임보가능', '릴레이임보'],
#   '공고날짜 ': '2025-02-02',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '소미',
#   '종': None},
#  {'ID': '1640',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-01-20',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '노랑이',
#   '종': None},
#  {'ID': '1635',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-01-19',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '샛별',
#   '종': None},
#  {'ID': '1538',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-01-06',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '동물구조119_스노우',
#   '종': None},
#  {'ID': '1537',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2025-01-06',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '동물구조119_화이트',
#   '종': None},
#  {'ID': '1524',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2025-01-04',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '이브',
#   '종': None},
#  {'ID': '1507',
#   'tags': ['임보가능', '입양전제'],
#   '공고날짜 ': '2025-01-01',
#   '몸무게': '7kg',
#   '성별': '남',
#   '이름': '힘찬이',
#   '종': '믹스'},
#  {'ID': '1496',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-12-30',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '꼬등',
#   '종': None},
#  {'ID': '1413',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-12-15',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '이금(조선왕 영조의 이름) ',
#   '종': None},
#  {'ID': '1380',
#   'tags': ['임보중', '긴급임보'],
#   '공고날짜 ': '2024-12-10',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '두부',
#   '종': '믹스'},
#  {'ID': '1317',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-11-28',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '어독스 유솔',
#   '종': None},
#  {'ID': '1300',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-11-25',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '강동냥이_깻잎이',
#   '종': None},
#  {'ID': '1280',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-11-22',
#   '몸무게': '08kg',
#   '성별': '남',
#   '이름': '레오',
#   '종': None},
#  {'ID': '1233',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-11-15',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '체체',
#   '종': None},
#  {'ID': '1229',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-11-15',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '체다',
#   '종': None},
#  {'ID': '1083',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-10-26',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '철수',
#   '종': None},
#  {'ID': '1039',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-10-15',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '김삼순',
#   '종': None},
#  {'ID': '1032',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-10-14',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '로즈',
#   '종': None},
#  {'ID': '1030',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-10-14',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '모찌',
#   '종': '믹스'},
#  {'ID': '991',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-10-08',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '두치',
#   '종': None},
#  {'ID': '871',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-09-07',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '미로',
#   '종': None},
#  {'ID': '860',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-09-04',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '옹심이',
#   '종': None},
#  {'ID': '857',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-09-02',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '숲이',
#   '종': None},
#  {'ID': '856',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-09-02',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '꿈이',
#   '종': None},
#  {'ID': '853',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-09-02',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '흰둥이',
#   '종': None},
#  {'ID': '814',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-08-21',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '삼남매-삼월',
#   '종': None},
#  {'ID': '812',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-08-21',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '삼남매-삼동',
#   '종': None},
#  {'ID': '769',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-08-10',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '가을이',
#   '종': None},
#  {'ID': '764',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-08-08',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '콩심이',
#   '종': None},
#  {'ID': '720',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-07-28',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '꼬미',
#   '종': None},
#  {'ID': '690',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-07-22',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '또치',
#   '종': None},
#  {'ID': '675',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-07-20',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '봄',
#   '종': None},
#  {'ID': '674',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-07-20',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '꼬리',
#   '종': None},
#  {'ID': '659',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-07-17',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '초코',
#   '종': None},
#  {'ID': '576',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-07-01',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '딱지',
#   '종': None},
#  {'ID': '549',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-06-23',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '삼순이',
#   '종': '믹스'},
#  {'ID': '532',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-06-17',
#   '몸무게': '580kg',
#   '성별': '남',
#   '이름': '냥냥이',
#   '종': None},
#  {'ID': '506',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-06-11',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '개성 만점 카오스 &apos;랑이&apos;',
#   '종': None},
#  {'ID': '484',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-06-07',
#   '몸무게': '0241kg',
#   '성별': '남',
#   '이름': '이은미',
#   '종': None},
#  {'ID': '423',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-05-21',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '핑크',
#   '종': None},
#  {'ID': '410',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-05-15',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '무싹',
#   '종': None},
#  {'ID': '409',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-05-15',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '뻔순',
#   '종': None},
#  {'ID': '253',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-03-24',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '뿌까',
#   '종': None},
#  {'ID': '209',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-03-09',
#   '몸무게': '6kg',
#   '성별': '남',
#   '이름': '붕이',
#   '종': None},
#  {'ID': '183',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-03-01',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '봄이',
#   '종': None},
#  {'ID': '181',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-03-01',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '살구',
#   '종': None},
#  {'ID': '180',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-03-01',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '사랑이',
#   '종': None},
#  {'ID': '173',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-02-29',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '할리',
#   '종': None},
#  {'ID': '130',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-02-21',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '소리',
#   '종': None},
#  {'ID': '93',
#   'tags': ['임보중', '입양전제'],
#   '공고날짜 ': '2024-02-19',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '호동이',
#   '종': None},
#  {'ID': '65',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-02-16',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '메달',
#   '종': None},
#  {'ID': '62',
#   'tags': ['임보중', '일반임보'],
#   '공고날짜 ': '2024-02-16',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '만두',
#   '종': None},
#  {'ID': '2848',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-07-09',
#   '몸무게': '06kg',
#   '성별': '남',
#   '이름': '바바',
#   '종': '믹스'},
#  {'ID': '2844',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-07-09',
#   '몸무게': '06kg',
#   '성별': '남',
#   '이름': '다다',
#   '종': '믹스'},
#  {'ID': '2843',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-07-09',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '푸름이',
#   '종': '믹스'},
#  {'ID': '2834',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '잭슨',
#   '종': '믹스'},
#  {'ID': '2833',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-07-08',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '에디',
#   '종': '믹스'},
#  {'ID': '2701',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-06-18',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '치즈냥 라봉이',
#   '종': '믹스'},
#  {'ID': '2319',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-04-30',
#   '몸무게': '6kg',
#   '성별': '남',
#   '이름': '네발친_낙낙이',
#   '종': '믹스'},
#  {'ID': '2131',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-04-04',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '사랑',
#   '종': '믹스'},
#  {'ID': '2092',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-03-28',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '메오',
#   '종': '믹스'},
#  {'ID': '2091',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-03-28',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '테오',
#   '종': '믹스'},
#  {'ID': '2071',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-03-25',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '삼식이',
#   '종': '믹스'},
#  {'ID': '2070',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-03-25',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '삼돌이',
#   '종': '믹스'},
#  {'ID': '1763',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-02-09',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '누리',
#   '종': '믹스'},
#  {'ID': '1762',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-02-09',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '나나',
#   '종': '품종'},
#  {'ID': '1628',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-01-19',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '오즈',
#   '종': None},
#  {'ID': '1609',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-01-16',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '동그리',
#   '종': None},
#  {'ID': '1562',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-01-10',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '네발친_묭이',
#   '종': '믹스'},
#  {'ID': '1551',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-01-08',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '아가',
#   '종': '믹스'},
#  {'ID': '1521',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-01-04',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '구슬이',
#   '종': None},
#  {'ID': '1506',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2025-01-01',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '소담',
#   '종': '품종'},
#  {'ID': '1490',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-30',
#   '몸무게': '6kg',
#   '성별': '남',
#   '이름': '호밀이',
#   '종': None},
#  {'ID': '1416',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-15',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '도림이',
#   '종': None},
#  {'ID': '1411',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-15',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '이도(세종대왕) ',
#   '종': None},
#  {'ID': '1391',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-11',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '찰떡이',
#   '종': None},
#  {'ID': '1379',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-10',
#   '몸무게': '900kg',
#   '성별': '여',
#   '이름': '쫑이',
#   '종': None},
#  {'ID': '1378',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-10',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '까미',
#   '종': None},
#  {'ID': '1361',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-12-06',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '반반',
#   '종': None},
#  {'ID': '1315',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-11-27',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '체리',
#   '종': None},
#  {'ID': '1256',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-11-18',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '겨울이',
#   '종': None},
#  {'ID': '1153',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-11-01',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '유니',
#   '종': '믹스'},
#  {'ID': '1138',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-31',
#   '몸무게': '600kg',
#   '성별': '여',
#   '이름': '방순이',
#   '종': None},
#  {'ID': '1130',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-30',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '캣초딩치즈',
#   '종': None},
#  {'ID': '1129',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-30',
#   '몸무게': '05kg',
#   '성별': '여',
#   '이름': '까망이아가',
#   '종': None},
#  {'ID': '1128',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-30',
#   '몸무게': '05kg',
#   '성별': '여',
#   '이름': '카오스아가',
#   '종': None},
#  {'ID': '1127',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-30',
#   '몸무게': '05kg',
#   '성별': '여',
#   '이름': '고등아가',
#   '종': None},
#  {'ID': '1126',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-30',
#   '몸무게': '05kg',
#   '성별': '여',
#   '이름': '삼색아가',
#   '종': None},
#  {'ID': '1125',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-30',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '순이',
#   '종': None},
#  {'ID': '1096',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-27',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '또롱이',
#   '종': None},
#  {'ID': '1086',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-26',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '빵빵이',
#   '종': None},
#  {'ID': '1067',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-22',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '콩이',
#   '종': None},
#  {'ID': '1022',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-12',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '양재',
#   '종': None},
#  {'ID': '1002',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-10',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '삐빅이',
#   '종': '믹스'},
#  {'ID': '997',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-08',
#   '몸무게': '700kg',
#   '성별': '여',
#   '이름': '우리와 나라(남과 여)',
#   '종': None},
#  {'ID': '989',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-10-07',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '랑이',
#   '종': None},
#  {'ID': '930',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-09-21',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '탄이',
#   '종': None},
#  {'ID': '883',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-09-12',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '어독스 앙꼬',
#   '종': '믹스'},
#  {'ID': '773',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-08-11',
#   '몸무게': '172kg',
#   '성별': '남',
#   '이름': '딱지',
#   '종': None},
#  {'ID': '762',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-08-07',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '홍구',
#   '종': None},
#  {'ID': '761',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-08-07',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '생강이',
#   '종': None},
#  {'ID': '696',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-23',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '먼지',
#   '종': None},
#  {'ID': '686',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-21',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '난',
#   '종': None},
#  {'ID': '676',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-20',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '사랑이',
#   '종': '믹스'},
#  {'ID': '673',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-20',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '빵순이',
#   '종': None},
#  {'ID': '672',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-20',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '춘식이',
#   '종': None},
#  {'ID': '648',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-14',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '선물이',
#   '종': None},
#  {'ID': '647',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-14',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '장순이',
#   '종': None},
#  {'ID': '622',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-08',
#   '몸무게': '105kg',
#   '성별': '여',
#   '이름': '봄이',
#   '종': None},
#  {'ID': '595',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-02',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '토토',
#   '종': '품종'},
#  {'ID': '594',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-02',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '청이',
#   '종': None},
#  {'ID': '593',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-02',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '단이',
#   '종': None},
#  {'ID': '592',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-02',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '홍이',
#   '종': None},
#  {'ID': '590',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-02',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '어독스 춘자',
#   '종': '믹스'},
#  {'ID': '589',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-07-02',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '어독스 말자',
#   '종': None},
#  {'ID': '528',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-06-16',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '여름',
#   '종': None},
#  {'ID': '527',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-06-15',
#   '몸무게': '850kg',
#   '성별': '여',
#   '이름': '로이',
#   '종': None},
#  {'ID': '526',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-06-15',
#   '몸무게': '910kg',
#   '성별': '남',
#   '이름': '레이',
#   '종': None},
#  {'ID': '416',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-05-17',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '호랑 나비',
#   '종': None},
#  {'ID': '182',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-03-01',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '빵순이',
#   '종': None},
#  {'ID': '124',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-02-21',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '사과',
#   '종': None},
#  {'ID': '113',
#   'tags': ['입양완료'],
#   '공고날짜 ': '2024-02-21',
#   '몸무게': '3kg',
#   '성별': '남',
#   '이름': '어독스 최준',
#   '종': None},
#  {'ID': '2786',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-06-30',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '키위',
#   '종': '믹스'},
#  {'ID': '2648',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-06-09',
#   '몸무게': '4kg',
#   '성별': '남',
#   '이름': '봉이',
#   '종': '믹스'},
#  {'ID': '2449',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-05-22',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '별빛이',
#   '종': '믹스'},
#  {'ID': '2448',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-05-22',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '금빛이',
#   '종': '믹스'},
#  {'ID': '2260',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-04-20',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '치즈냥이',
#   '종': '믹스'},
#  {'ID': '1799',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-02-12',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '강동냥이_코점이',
#   '종': None},
#  {'ID': '1726',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-02-03',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '동물구조119_행운',
#   '종': None},
#  {'ID': '1698',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2025-01-27',
#   '몸무게': '3kg',
#   '성별': '여',
#   '이름': '클레오',
#   '종': None},
#  {'ID': '1449',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-12-20',
#   '몸무게': '08kg',
#   '성별': '남',
#   '이름': '이산',
#   '종': None},
#  {'ID': '1412',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-12-15',
#   '몸무게': '1kg',
#   '성별': '여',
#   '이름': '이향(문종의 이름) ',
#   '종': None},
#  {'ID': '1341',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-12-03',
#   '몸무게': '2kg',
#   '성별': '여',
#   '이름': '루팡',
#   '종': None},
#  {'ID': '1339',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-12-03',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '용맹',
#   '종': None},
#  {'ID': '1033',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-10-14',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '양복이',
#   '종': None},
#  {'ID': '842',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-08-28',
#   '몸무게': '5kg',
#   '성별': '여',
#   '이름': '흰둥이 (9월 1달)',
#   '종': None},
#  {'ID': '813',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-08-21',
#   '몸무게': '2kg',
#   '성별': '남',
#   '이름': '삼남매-삼식',
#   '종': None},
#  {'ID': '662',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-07-18',
#   '몸무게': '1kg',
#   '성별': '남',
#   '이름': '조랭이',
#   '종': None},
#  {'ID': '419',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-05-18',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '호빵이',
#   '종': None},
#  {'ID': '342',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-04-23',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '뱅쇼',
#   '종': None},
#  {'ID': '319',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-04-16',
#   '몸무게': '5kg',
#   '성별': '남',
#   '이름': '폴',
#   '종': None},
#  {'ID': '185',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-03-01',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '은별',
#   '종': '믹스'},
#  {'ID': '82',
#   'tags': ['공고종료'],
#   '공고날짜 ': '2024-02-17',
#   '몸무게': '4kg',
#   '성별': '여',
#   '이름': '꽃님이',
#   '종': None}]

# %%
import json 

with open('data/cat_data.json','w',encoding='utf-8') as file:
    json.dump(cat_data_list, file,ensure_ascii=False,indent=2)

# %%
import pandas as pd

cat_df = pd.read_json('data/cat_data.json')
print(type(cat_df))
cat_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      ID          tags          이름 성별   몸무게   종       공고날짜
# 0  2950  [임보가능, 입양전제]  나기 외 새끼고양이  여   1kg  믹스  2025-07-26
# 1  2927  [임보가능, 입양전제]         달봉이  여  08kg  믹스  2025-07-21
# 2  2897   [임보중, 입양전제]          콩이  여   3kg  믹스  2025-07-16
# 3  2893   [임보중, 입양전제]          로담  남   4kg  품종  2025-07-15
# 4  2860   [임보중, 입양전제]          로아  여  06kg  믹스  2025-07-10

# %%
cat_df.explode('tags')['tags'].value_counts()
# Out:
# tags
# 입양완료     70
# 임보중      60
# 입양전제     51
# 일반임보     45
# 임보가능     40
# 공고종료     35
# 릴레이임보     2
# 단기임보      1
# 긴급임보      1
# Name: count, dtype: int64

# %%
cat_df.loc[cat_df['tags'].apply(lambda x: '입양완료' not in x and '공고종료' not in x)].reset_index()
# Out:
#     index    ID          tags          이름 성별   몸무게     종       공고날짜
# 0       0  2950  [임보가능, 입양전제]  나기 외 새끼고양이  여   1kg    믹스  2025-07-26
# 1       1  2927  [임보가능, 입양전제]         달봉이  여  08kg    믹스  2025-07-21
# 2       2  2897   [임보중, 입양전제]          콩이  여   3kg    믹스  2025-07-16
# 3       3  2893   [임보중, 입양전제]          로담  남   4kg    품종  2025-07-15
# 4       4  2860   [임보중, 입양전제]          로아  여  06kg    믹스  2025-07-10
# ..    ...   ...           ...         ... ..   ...   ...         ...
# 95    108   180   [임보중, 일반임보]         사랑이  남   3kg  None  2024-03-01
# 96    109   173   [임보중, 일반임보]          할리  여   3kg  None  2024-02-29
# 97    110   130   [임보중, 입양전제]          소리  여   4kg  None  2024-02-21
# 98    111    93   [임보중, 입양전제]         호동이  남   5kg  None  2024-02-19
# 99    113    62   [임보중, 일반임보]          만두  남   2kg  None  2024-02-16
#
# [100 rows x 8 columns]

# %%
cat_df.loc[cat_df['tags'].apply(lambda x: '입양완료' in x )].reset_index()
# Out:
#     index    ID    tags      이름 성별    몸무게     종       공고날짜
# 0     114  2848  [입양완료]      바바  남   06kg    믹스  2025-07-09
# 1     115  2844  [입양완료]      다다  남   06kg    믹스  2025-07-09
# 2     116  2843  [입양완료]     푸름이  남    1kg    믹스  2025-07-09
# 3     117  2834  [입양완료]      잭슨  남    3kg    믹스  2025-07-08
# 4     118  2833  [입양완료]      에디  남    3kg    믹스  2025-07-08
# ..    ...   ...     ...     ... ..    ...   ...         ...
# 65    179   526  [입양완료]      레이  남  910kg  None  2024-06-15
# 66    180   416  [입양완료]   호랑 나비  남    4kg  None  2024-05-17
# 67    181   182  [입양완료]     빵순이  여    4kg  None  2024-03-01
# 68    182   124  [입양완료]      사과  여    2kg  None  2024-02-21
# 69    183   113  [입양완료]  어독스 최준  남    3kg  None  2024-02-21
#
# [70 rows x 8 columns]

# %%
cat_df.loc[cat_df['tags'].apply(lambda x: '공고종료' in x)].reset_index()
# Out:
#     index    ID    tags                        이름 성별   몸무게     종       공고날짜
# 0      69  1496  [공고종료]                        꼬등  남   5kg  None  2024-12-30
# 1      73  1300  [공고종료]                  강동냥이_깻잎이  여   5kg  None  2024-11-25
# 2      79  1032  [공고종료]                        로즈  여   3kg  None  2024-10-14
# 3      80  1030  [공고종료]                        모찌  여   1kg    믹스  2024-10-14
# 4      83   860  [공고종료]                       옹심이  여   4kg  None  2024-09-04
# 5      90   764  [공고종료]                       콩심이  여   3kg  None  2024-08-08
# 6      93   675  [공고종료]                         봄  여   4kg  None  2024-07-20
# 7      97   549  [공고종료]                       삼순이  여   4kg    믹스  2024-06-23
# 8      99   506  [공고종료]  개성 만점 카오스 &apos;랑이&apos;  여   2kg  None  2024-06-11
# 9     102   410  [공고종료]                        무싹  남   4kg  None  2024-05-15
# 10    103   409  [공고종료]                        뻔순  여   4kg  None  2024-05-15
# 11    106   183  [공고종료]                        봄이  여   3kg  None  2024-03-01
# 12    107   181  [공고종료]                        살구  남   4kg  None  2024-03-01
# 13    112    65  [공고종료]                        메달  여   3kg  None  2024-02-16
# 14    184  2786  [공고종료]                        키위  여   1kg    믹스  2025-06-30
# 15    185  2648  [공고종료]                        봉이  남   4kg    믹스  2025-06-09
# 16    186  2449  [공고종료]                       별빛이  여   1kg    믹스  2025-05-22
# 17    187  2448  [공고종료]                       금빛이  여   1kg    믹스  2025-05-22
# 18    188  2260  [공고종료]                      치즈냥이  여   3kg    믹스  2025-04-20
# 19    189  1799  [공고종료]                  강동냥이_코점이  여   5kg  None  2025-02-12
# 20    190  1726  [공고종료]                동물구조119_행운  여   3kg  None  2025-02-03
# 21    191  1698  [공고종료]                       클레오  여   3kg  None  2025-01-27
# 22    192  1449  [공고종료]                        이산  남  08kg  None  2024-12-20
# 23    193  1412  [공고종료]               이향(문종의 이름)   여   1kg  None  2024-12-15
# 24    194  1341  [공고종료]                        루팡  여   2kg  None  2024-12-03
# 25    195  1339  [공고종료]                        용맹  남   2kg  None  2024-12-03
# 26    196  1033  [공고종료]                       양복이  남   2kg  None  2024-10-14
# 27    197   842  [공고종료]               흰둥이 (9월 1달)  여   5kg  None  2024-08-28
# 28    198   813  [공고종료]                    삼남매-삼식  남   2kg  None  2024-08-21
# 29    199   662  [공고종료]                       조랭이  남   1kg  None  2024-07-18
# 30    200   419  [공고종료]                       호빵이  남   5kg  None  2024-05-18
# 31    201   342  [공고종료]                        뱅쇼  여   4kg  None  2024-04-23
# 32    202   319  [공고종료]                         폴  남   5kg  None  2024-04-16
# 33    203   185  [공고종료]                        은별  여   4kg    믹스  2024-03-01
# 34    204    82  [공고종료]                       꽃님이  여   4kg  None  2024-02-17

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
[(font.name, font.fname) for font in fm.fontManager.ttflist if 'Mal' in font.name ]
# Out:
# [('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf')]

# %%
font_path = 'C:\\windows\\Fonts\\malgun.ttf'
#font의 파일정보로 font name 을 알아내기
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)

matplotlib.rc('font',family=font_prop)
# Out:
# Malgun Gothic

# %%
# 한글 폰트 오류 방지 (윈도우라면 필요)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
def classify_status(tag_list):
    if '공고종료' in tag_list:
        return '공고종료'
    elif '입양완료' in tag_list:
        return '입양완료'
    elif '임보중' in tag_list:
        return '임보중'
    else:
        return '임보가능'

cat_df['현재 상태'] = cat_df['tags'].apply(classify_status)

status_order = cat_df['현재 상태'].value_counts().sort_values(ascending=False).index.tolist()

plt.figure(figsize=(12, 7))
sns.countplot(data=cat_df, x='현재 상태',order=status_order,palette='pastel')
plt.title('임보 고양이 분포')
plt.xlabel('')
plt.ylabel('')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28680\3029408801.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=cat_df, x='현재 상태',order=status_order,palette='pastel')

# %%
status_counts = cat_df['현재 상태'].value_counts()

labels = status_counts.index
sizes = status_counts.values

plt.figure(figsize=(8, 8))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140
)
plt.title('임보 고양이 비율')
plt.show()
